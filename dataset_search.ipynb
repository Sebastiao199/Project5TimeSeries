# %%
import pandas as pd

# %%
alfred_homeindex_notseasonally = pd.read_excel('alfredgraph_notseasonally.xls')
alfred_homeindex_notseasonally.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ALFRED Graph Observations  438 non-null    object
#  1   Unnamed: 1                 431 non-null    object
#  2   Unnamed: 2                 430 non-null    object
# dtypes: object(3)
# memory usage: 10.4+ KB

# %%
alfred_homeindex_notseasonally.head(20)
# Out:
#                    ALFRED Graph Observations  \
# 0     Archival Federal Reserve Economic Data
# 1        Link: https://alfred.stlouisfed.org
# 2   Help: https://alfred.stlouisfed.org/help
# 3                 Economic Research Division
# 4          Federal Reserve Bank of St. Louis
# 5                                        NaN
# 6                           SFXRNSA_20221025
# 7                           SFXRNSA_20221129
# 8                                        NaN
# 9                         Frequency: Monthly
# 10                          observation_date
# 11                       1987-01-01 00:00:00
# 12                       1987-02-01 00:00:00
# 13                       1987-03-01 00:00:00
# 14                       1987-04-01 00:00:00
# 15                       1987-05-01 00:00:00
# 16                       1987-06-01 00:00:00
# 17                       1987-07-01 00:00:00
# 18                       1987-08-01 00:00:00
# 19                       1987-09-01 00:00:00
#
# ...

# %%
alfred_homeindex_seasonally = pd.read_excel('alfredgraph_seasonally.xls')
alfred_homeindex_seasonally.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ALFRED Graph Observations  438 non-null    object
#  1   Unnamed: 1                 431 non-null    object
#  2   Unnamed: 2                 430 non-null    object
# dtypes: object(3)
# memory usage: 10.4+ KB

# %%
alfred_homeindex_seasonally.head(20)
# Out:
#                    ALFRED Graph Observations  \
# 0     Archival Federal Reserve Economic Data
# 1        Link: https://alfred.stlouisfed.org
# 2   Help: https://alfred.stlouisfed.org/help
# 3                 Economic Research Division
# 4          Federal Reserve Bank of St. Louis
# 5                                        NaN
# 6                            SFXRSA_20221025
# 7                            SFXRSA_20221129
# 8                                        NaN
# 9                         Frequency: Monthly
# 10                          observation_date
# 11                       1993-12-01 00:00:00
# 12                       1994-01-01 00:00:00
# 13                       1994-02-01 00:00:00
# 14                       1994-03-01 00:00:00
# 15                       1994-04-01 00:00:00
# 16                       1994-05-01 00:00:00
# 17                       1994-06-01 00:00:00
# 18                       1994-07-01 00:00:00
# 19                       1994-08-01 00:00:00
#
# ...
